# %%
1. Scenario: A company wants to analyze the sales performance of its products in different regions. They have collected the following data:
   Region A: [10, 15, 12, 8, 14]
   Region B: [18, 20, 16, 22, 25]
   Calculate the mean sales for each region.

# %% [raw]
# To calculate the mean sales for each region, you need to find the average of the sales data in each region. Here's how you can do it:
#
# For Region A:
# Sales data: [10, 15, 12, 8, 14]
# To find the mean, add up all the values and divide by the total number of values:
# Mean = (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
#
# Therefore, the mean sales for Region A is 11.8.
#
# For Region B:
# Sales data: [18, 20, 16, 22, 25]
# To find the mean, add up all the values and divide by the total number of values:
# Mean = (18 + 20 + 16 + 22 + 25) / 5 = 101 / 5 = 20.2
#
# Therefore, the mean sales for Region B is 20.2.
#
# In summary, the mean sales for Region A is 11.8, and the mean sales for Region B is 20.2.

# %%
2. Scenario: A survey is conducted to measure customer satisfaction on a scale of 1 to 5. The data collected is as follows:
   [4, 5, 2, 3, 5, 4, 3, 2, 4, 5]
   Calculate the mode of the survey responses.

# %% [raw]
# To calculate the mode of the survey responses, you need to find the value that appears most frequently in the data set. In this case, the data set is [4, 5, 2, 3, 5, 4, 3, 2, 4, 5].
#
# Let's count the frequency of each value:
#
# Value 2 appears twice.
# Value 3 appears twice.
# Value 4 appears three times.
# Value 5 appears three times.
# The mode is the value that occurs most frequently. In this case, both 4 and 5 appear three times, so we have multiple modes. Therefore, the modes of the survey responses are 4 and 5.

# %%
3. Scenario: A company wants to compare the salaries of two departments. The salary data for Department A and Department B are as follows:
   Department A: [5000, 6000, 5500, 7000]
   Department B: [4500, 5500, 5800, 6000, 5200]
   Calculate the median salary for each department.

# %% [raw]
# To calculate the median salary for each department, you need to find the middle value in the sorted salary data. Here's how you can do it:
#
# For Department A:
# Salary data: [5000, 6000, 5500, 7000]
# Step 1: Sort the salary data in ascending order: [5000, 5500, 6000, 7000]
# Step 2: Find the middle value. In this case, there are four values, so the median is the average of the two middle values:
# Median = (5500 + 6000) / 2 = 11500 / 2 = 5750
#
# Therefore, the median salary for Department A is 5750.
#
# For Department B:
# Salary data: [4500, 5500, 5800, 6000, 5200]
# Step 1: Sort the salary data in ascending order: [4500, 5200, 5500, 5800, 6000]
# Step 2: Find the middle value. In this case, there are five values, so the median is the middle value:
# Median = 5500
#
# Therefore, the median salary for Department B is 5500.
#
# In summary, the median salary for Department A is 5750, and the median salary for Department B is 5500.

# %%
4. Scenario: A data analyst wants to determine the variability in the daily stock prices of a company. The data collected is as follows:
   [25.5, 24.8, 26.1, 25.3, 24.9]
   Calculate the range of the stock prices.

# %% [raw]
# To calculate the range of the stock prices, you need to find the difference between the highest and lowest values in the data set. Here's how you can do it:
#
# Stock prices: [25.5, 24.8, 26.1, 25.3, 24.9]
#
# Step 1: Sort the stock prices in ascending order: [24.8, 24.9, 25.3, 25.5, 26.1]
#
# Step 2: Find the highest value and the lowest value.
#
# The highest value is 26.1, and the lowest value is 24.8.
#
# Step 3: Calculate the range by subtracting the lowest value from the highest value:
#
# Range = Highest value - Lowest value = 26.1 - 24.8 = 1.3
#
# Therefore, the range of the stock prices is 1.3.

# %%
5. Scenario: A study is conducted to compare the performance of two different teaching methods. The test scores of the students in each group are as follows:
   Group A: [85, 90, 92, 88, 91]
   Group B: [82, 88, 90, 86, 87]
   Perform a t-test to determine if there is a significant difference in the mean scores between the two groups.

# %% [raw]
# To perform a t-test and determine if there is a significant difference in the mean scores between Group A and Group B, we can follow these steps:
#
# Step 1: Define the null hypothesis (H0) and the alternative hypothesis (H1):
#
# Null hypothesis (H0): There is no significant difference in the mean scores between Group A and Group B.
# Alternative hypothesis (H1): There is a significant difference in the mean scores between Group A and Group B.
# Step 2: Calculate the means and standard deviations for each group:
#
# Group A:
# Scores: [85, 90, 92, 88, 91]
# Mean (μA): (85 + 90 + 92 + 88 + 91) / 5 = 446 / 5 = 89.2
# Standard deviation (σA): 2.83
#
# Group B:
# Scores: [82, 88, 90, 86, 87]
# Mean (μB): (82 + 88 + 90 + 86 + 87) / 5 = 433 / 5 = 86.6
# Standard deviation (σB): 2.97
#
# Step 3: Calculate the t-value using the formula:
#
# t = (μA - μB) / sqrt((σA^2 / nA) + (σB^2 / nB))
#
# where:
# μA and μB are the means of Group A and Group B, respectively,
# σA and σB are the standard deviations of Group A and Group B, respectively,
# nA and nB are the sample sizes of Group A and Group B, respectively.
#
# t = (89.2 - 86.6) / sqrt((2.83^2 / 5) + (2.97^2 / 5))
# t = 2.6 / sqrt(0.8 + 0.876)
# t = 2.6 / sqrt(1.676)
# t = 2.6 / 1.294
# t ≈ 2.007
#
# Step 4: Determine the degrees of freedom (df) based on the sample sizes:
#
# df = nA + nB - 2
# df = 5 + 5 - 2
# df = 8
#
# Step 5: Look up the critical t-value for the desired significance level and degrees of freedom. Let's assume a significance level of 0.05.
#
# For a two-tailed t-test with a significance level of 0.05 and df = 8, the critical t-value is approximately ±2.306.
#
# Step 6: Compare the calculated t-value with the critical t-value:
#
# Since the calculated t-value (2.007) is less than the critical t-value (±2.306), we fail to reject the null hypothesis.
#
# Therefore, based on the t-test, there is not enough evidence to conclude that there is a significant difference in the mean scores between Group A and Group B.

# %%
6. Scenario: A company wants to analyze the relationship between advertising expenditure and sales. The data collected is as follows:
   Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
   Sales (in thousands): [25, 30, 28, 20, 26]
   Calculate the correlation coefficient between advertising expenditure and sales.

# %% [raw]
# To calculate the correlation coefficient between advertising expenditure and sales, we can use the Pearson correlation coefficient formula. Here's how you can calculate it:
#
# Step 1: Calculate the means of the advertising expenditure and sales data:
#
# Advertising expenditure (in thousands): [10, 15, 12, 8, 14]
# Mean expenditure (μx) = (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
#
# Sales (in thousands): [25, 30, 28, 20, 26]
# Mean sales (μy) = (25 + 30 + 28 + 20 + 26) / 5 = 129 / 5 = 25.8
#
# Step 2: Calculate the deviations from the means for both variables:
#
# Advertising expenditure deviations: [(10 - 11.8), (15 - 11.8), (12 - 11.8), (8 - 11.8), (14 - 11.8)] = [-1.8, 3.2, 0.2, -3.8, 2.2]
# Sales deviations: [(25 - 25.8), (30 - 25.8), (28 - 25.8), (20 - 25.8), (26 - 25.8)] = [-0.8, 4.2, 2.2, -5.8, 0.2]
#
# Step 3: Calculate the product of the deviations for each pair of data points:
#
# Deviations product: [-1.8 * -0.8, 3.2 * 4.2, 0.2 * 2.2, -3.8 * -5.8, 2.2 * 0.2] = [1.44, 13.44, 0.44, 22.04, 0.44]
#
# Step 4: Calculate the sum of the product of the deviations:
#
# Sum of deviations product = 1.44 + 13.44 + 0.44 + 22.04 + 0.44 = 37.8
#
# Step 5: Calculate the standard deviation of advertising expenditure (σx) and sales (σy):
#
# Standard deviation of advertising expenditure (σx) = sqrt([(10 - 11.8)^2 + (15 - 11.8)^2 + (12 - 11.8)^2 + (8 - 11.8)^2 + (14 - 11.8)^2] / 4) ≈ 2.15
# Standard deviation of sales (σy) = sqrt([(25 - 25.8)^2 + (30 - 25.8)^2 + (28 - 25.8)^2 + (20 - 25.8)^2 + (26 - 25.8)^2] / 4) ≈ 2.57
#
# Step 6: Calculate the correlation coefficient (r) using the formula:
#
# r = (Sum of deviations product) / (n * σx * σy)
#
# r = 37.8 / (5 * 2.15 * 2.57) ≈ 1.41
#
# Therefore, the correlation coefficient between advertising expenditure and sales is approximately 1.41. Note that the correlation coefficient ranges from -1 to +1, where +1 indicates a strong positive correlation, -1 indicates a strong negative correlation, and 0 indicates no correlation. In this case, the positive correlation coefficient suggests a moderate positive relationship between advertising expenditure and sales.

# %%
7. Scenario: A survey is conducted to measure the heights of a group of people. The data collected is as follows:
   [160, 170, 165, 155, 175, 180, 170]
   Calculate the standard deviation of the heights.

# %% [raw]
# To calculate the standard deviation of the heights, you can follow these steps:
#
# Step 1: Calculate the mean (average) height:
# Height data: [160, 170, 165, 155, 175, 180, 170]
# Mean height (μ) = (160 + 170 + 165 + 155 + 175 + 180 + 170) / 7 = 1175 / 7 ≈ 167.86
#
# Step 2: Calculate the deviations from the mean for each height:
# Deviations: [160 - 167.86, 170 - 167.86, 165 - 167.86, 155 - 167.86, 175 - 167.86, 180 - 167.86, 170 - 167.86]
# Deviations: [-7.86, 2.14, -2.86, -12.86, 7.14, 12.14, 2.14]
#
# Step 3: Square each deviation:
# Squared deviations: [(-7.86)^2, (2.14)^2, (-2.86)^2, (-12.86)^2, (7.14)^2, (12.14)^2, (2.14)^2]
# Squared deviations: [61.67, 4.58, 8.20, 165.17, 51.04, 147.60, 4.58]
#
# Step 4: Calculate the mean of the squared deviations (variance):
# Variance = (61.67 + 4.58 + 8.20 + 165.17 + 51.04 + 147.60 + 4.58) / 7 ≈ 56.17
#
# Step 5: Take the square root of the variance to calculate the standard deviation:
# Standard deviation = sqrt(Variance) ≈ sqrt(56.17) ≈ 7.49
#
# Therefore, the standard deviation of the heights is approximately 7.49. The standard deviation measures the dispersion or spread of the heights from the mean value, indicating how much the heights vary from the average.

# %%
8. Scenario: A company wants to analyze the relationship between employee tenure and job satisfaction. The data collected is as follows:
   Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
   Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
   Perform a linear regression analysis to predict job satisfaction based on employee tenure.

# %% [raw]
# To perform a linear regression analysis to predict job satisfaction based on employee tenure, you can follow these steps:
#
# Step 1: Organize the data:
# Employee Tenure (in years): [2, 3, 5, 4, 6, 2, 4]
# Job Satisfaction (on a scale of 1 to 10): [7, 8, 6, 9, 5, 7, 6]
#
# Step 2: Calculate the means of the employee tenure and job satisfaction data:
#
# Mean tenure (μx) = (2 + 3 + 5 + 4 + 6 + 2 + 4) / 7 = 26 / 7 ≈ 3.71
# Mean satisfaction (μy) = (7 + 8 + 6 + 9 + 5 + 7 + 6) / 7 = 48 / 7 ≈ 6.86
#
# Step 3: Calculate the deviations from the means for both variables:
#
# Tenure deviations: [(2 - 3.71), (3 - 3.71), (5 - 3.71), (4 - 3.71), (6 - 3.71), (2 - 3.71), (4 - 3.71)] ≈ [-1.71, -0.71, 1.29, 0.29, 2.29, -1.71, 0.29]
# Satisfaction deviations: [(7 - 6.86), (8 - 6.86), (6 - 6.86), (9 - 6.86), (5 - 6.86), (7 - 6.86), (6 - 6.86)] ≈ [0.14, 1.14, -0.86, 2.14, -1.86, 0.14, -0.86]
#
# Step 4: Calculate the product of the deviations for each pair of data points:
#
# Deviations product: [-1.71 * 0.14, -0.71 * 1.14, 1.29 * -0.86, 0.29 * 2.14, 2.29 * -1.86, -1.71 * 0.14, 0.29 * -0.86] ≈ [-0.24, -0.81, -1.11, 0.62, -4.26, -0.24, -0.25]
#
# Step 5: Calculate the squared deviations for each variable:
#
# Tenure squared deviations: [(-1.71)^2, (-0.71)^2, (1.29)^2, (0.29)^2, (2.29)^2, (-1.71)^2, (0.29)^2] ≈ [2.93, 0.51, 1.66, 0.08, 5.24, 2.93, 0.08]
# Satisfaction squared deviations: [(0.14)^2, (1.14)^2, (-0.86)^2, (2.14)^2, (-1.86)^2, (0.14)^2, (-0.86)^2] ≈ [0.02, 1.30, 0.74, 4.58, 3.46, 0.02, 0.74]
#
# Step 6: Calculate the sum of the product of the deviations and the sum of the squared deviations:
#
# Sum of deviations product = -0.24 + -0.81 + -1.11 + 0.62 + -4.26 + -0.24 + -0.25 ≈ -6.09
# Sum of tenure squared deviations = 2.93 + 0.51 + 1.66 + 0.08 + 5.24 + 2.93 + 0.08 ≈ 13.53
# Sum of satisfaction squared deviations = 0.02 + 1.30 + 0.74 + 4.58 + 3.46 + 0.02 + 0.74 ≈ 10.86
#
# Step 7: Calculate the slope (β1) of the regression line:
#
# β1 = (Sum of deviations product) / (Sum of tenure squared deviations) = -6.09 / 13.53 ≈ -0.45
#
# Step 8: Calculate the y-intercept (β0) of the regression line:
#
# β0 = μy - (β1 * μx) = 6.86 - (-0.45 * 3.71) ≈ 8.47
#
# Step 9: Write the equation of the regression line:
#
# Job Satisfaction = β0 + β1 * Employee Tenure
# Job Satisfaction = 8.47 + (-0.45 * Employee Tenure)
#
# Therefore, the equation of the regression line to predict job satisfaction based on employee tenure is approximately:
# Job Satisfaction = 8.47 - 0.45 * Employee Tenure

# %%
9. Scenario: A study is conducted to compare the effectiveness of two different medications. The recovery times of the patients in each group are as follows:
   Medication A: [10, 12, 14, 11, 13]
   Medication B: [15, 17, 16, 14, 18]
   Perform an analysis of variance (ANOVA) to determine if there is a significant difference in the mean recovery times between the two medications.

# %% [raw]
# To perform an analysis of variance (ANOVA) and determine if there is a significant difference in the mean recovery times between Medication A and Medication B, you can follow these steps:
#
# Step 1: Define the null hypothesis (H0) and the alternative hypothesis (H1):
#
# Null hypothesis (H0): There is no significant difference in the mean recovery times between Medication A and Medication B.
# Alternative hypothesis (H1): There is a significant difference in the mean recovery times between Medication A and Medication B.
# Step 2: Calculate the means and sum of squares for each group:
#
# Medication A:
# Recovery times: [10, 12, 14, 11, 13]
# Mean (μA): (10 + 12 + 14 + 11 + 13) / 5 = 60 / 5 = 12
# Sum of squares (SSA) = (10 - 12)^2 + (12 - 12)^2 + (14 - 12)^2 + (11 - 12)^2 + (13 - 12)^2 = 8 + 0 + 4 + 1 + 1 = 14
#
# Medication B:
# Recovery times: [15, 17, 16, 14, 18]
# Mean (μB): (15 + 17 + 16 + 14 + 18) / 5 = 80 / 5 = 16
# Sum of squares (SSB) = (15 - 16)^2 + (17 - 16)^2 + (16 - 16)^2 + (14 - 16)^2 + (18 - 16)^2 = 1 + 1 + 0 + 4 + 4 = 10
#
# Step 3: Calculate the total sum of squares (SST):
#
# SST = SSA + SSB = 14 + 10 = 24
#
# Step 4: Calculate the degrees of freedom (df) for each component:
#
# dfA = number of observations in Medication A - 1 = 5 - 1 = 4
# dfB = number of observations in Medication B - 1 = 5 - 1 = 4
# dfT = total number of observations - 1 = 10 - 1 = 9
#
# Step 5: Calculate the mean sum of squares (MSA and MSB) for each component:
#
# MSA = SSA / dfA = 14 / 4 = 3.5
# MSB = SSB / dfB = 10 / 4 = 2.5
#
# Step 6: Calculate the F-value using the formula:
#
# F = MSA / MSB = 3.5 / 2.5 = 1.4
#
# Step 7: Look up the critical F-value for the desired significance level and degrees of freedom. Let's assume a significance level of 0.05.
#
# For a two-tailed F-test with a significance level of 0.05, dfA = 4 and dfB = 4, the critical F-value is approximately 3.10.
#
# Step 8: Compare the calculated F-value with the critical F-value:
#
# Since the calculated F-value (1.4) is less than the critical F-value (3.10), we fail to reject the null hypothesis.
#
# Therefore, based on the ANOVA, there is not enough evidence to conclude that there is a significant difference in the mean recovery times between Medication A and Medication B.

# %%
10. Scenario: A company wants to analyze customer feedback ratings on a scale of 1 to 10. The data collected is

 as follows:
    [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
    Calculate the 75th percentile of the feedback ratings.

# %% [raw]
# To calculate the 75th percentile of the feedback ratings, you need to arrange the data in ascending order and find the value that corresponds to the position of the 75th percentile. Here's how you can do it:
#
# Feedback ratings: [8, 9, 7, 6, 8, 10, 9, 8, 7, 8]
#
# Step 1: Sort the feedback ratings in ascending order: [6, 7, 7, 8, 8, 8, 8, 9, 9, 10]
#
# Step 2: Calculate the position of the 75th percentile:
# Position = (75 / 100) * (n + 1)
# Position = (75 / 100) * (10 + 1)
# Position = (0.75) * (11)
# Position ≈ 8.25
#
# Step 3: Since the position (8.25) falls between the 8th and 9th values in the sorted data, we need to interpolate to find the 75th percentile.
#
# Interpolation formula: Value = Value at lower position + (Position - Lower position) * (Value at higher position - Value at lower position)
#
# Value = 8 + (8.25 - 8) * (8 - 9)
# Value = 8 + (0.25) * (-1)
# Value = 8 - 0.25
# Value = 7.75
#
# Therefore, the 75th percentile of the feedback ratings is approximately 7.75. This means that 75% of the feedback ratings are less than or equal to 7.75.

# %%
11. Scenario: A quality control department wants to test the weight consistency of a product. The weights of a sample of products are as follows:
    [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
    Perform a hypothesis test to determine if the mean weight differs significantly from 10 grams.

# %% [raw]
# To perform a hypothesis test and determine if the mean weight differs significantly from 10 grams, you can follow these steps:
#
# Step 1: Define the null hypothesis (H0) and the alternative hypothesis (H1):
#
# Null hypothesis (H0): The mean weight is equal to 10 grams.
# Alternative hypothesis (H1): The mean weight differs significantly from 10 grams.
# Step 2: Calculate the sample mean and standard deviation:
#
# Weight data: [10.2, 9.8, 10.0, 10.5, 10.3, 10.1]
#
# Sample mean (x̄) = (10.2 + 9.8 + 10.0 + 10.5 + 10.3 + 10.1) / 6 ≈ 10.17
# Sample standard deviation (s) = sqrt([(10.2 - 10.17)^2 + (9.8 - 10.17)^2 + (10.0 - 10.17)^2 + (10.5 - 10.17)^2 + (10.3 - 10.17)^2 + (10.1 - 10.17)^2] / 5) ≈ 0.24
#
# Step 3: Determine the test statistic (t-value) using the formula:
#
# t = (x̄ - μ) / (s / sqrt(n))
#
# where:
# x̄ is the sample mean,
# μ is the hypothesized mean (10 grams),
# s is the sample standard deviation,
# n is the sample size.
#
# t = (10.17 - 10) / (0.24 / sqrt(6)) ≈ 1.03
#
# Step 4: Determine the degrees of freedom (df) based on the sample size (n - 1):
#
# df = 6 - 1 = 5
#
# Step 5: Look up the critical t-value for the desired significance level and degrees of freedom. Let's assume a significance level of 0.05 (two-tailed test).
#
# For a two-tailed t-test with a significance level of 0.05 and df = 5, the critical t-value is approximately ±2.571.
#
# Step 6: Compare the calculated t-value with the critical t-value:
#
# Since the calculated t-value (1.03) is less than the critical t-value (±2.571), we fail to reject the null hypothesis.
#
# Therefore, based on the hypothesis test, there is not enough evidence to conclude that the mean weight differs significantly from 10 grams.

# %%
12. Scenario: A company wants to analyze the click-through rates of two different website designs. The number of clicks for each design is as follows:
    Design A: [100, 120, 110, 90, 95]
    Design B: [80, 85, 90, 95, 100]
    Perform a chi-square test to determine if there is a significant difference in the click-through rates between the two designs.

# %% [raw]
# To perform a chi-square test and determine if there is a significant difference in the click-through rates between Design A and Design B, you can follow these steps:
#
# Step 1: Define the null hypothesis (H0) and the alternative hypothesis (H1):
#
# Null hypothesis (H0): There is no significant difference in the click-through rates between Design A and Design B.
# Alternative hypothesis (H1): There is a significant difference in the click-through rates between Design A and Design B.
# Step 2: Create a contingency table:
#
# css
# Copy code
#     | Design A | Design B | Total
# Clicks | 100 | 80 | 180
# Clicks | 120 | 85 | 205
# Clicks | 110 | 90 | 200
# Clicks | 90 | 95 | 185
# Clicks | 95 | 100 | 195
# Total | 515 | 450 | 965
#
# Step 3: Calculate the expected frequencies for each cell:
#
# Expected frequency = (row total * column total) / grand total
#
# Expected frequency for cell (1,1) = (180 * 515) / 965 ≈ 95.54
# Expected frequency for cell (1,2) = (180 * 450) / 965 ≈ 84.13
# Expected frequency for cell (2,1) = (205 * 515) / 965 ≈ 109.43
# Expected frequency for cell (2,2) = (205 * 450) / 965 ≈ 95.57
# Expected frequency for cell (3,1) = (200 * 515) / 965 ≈ 107.36
# Expected frequency for cell (3,2) = (200 * 450) / 965 ≈ 92.64
# Expected frequency for cell (4,1) = (185 * 515) / 965 ≈ 98.89
# Expected frequency for cell (4,2) = (185 * 450) / 965 ≈ 86.11
# Expected frequency for cell (5,1) = (195 * 515) / 965 ≈ 104.79
# Expected frequency for cell (5,2) = (195 * 450) / 965 ≈ 90.21
#
# Step 4: Calculate the chi-square test statistic:
#
# Chi-square test statistic = Σ [(Observed frequency - Expected frequency)^2 / Expected frequency]
#
# Chi-square test statistic = [(100 - 95.54)^2 / 95.54] + [(80 - 84.13)^2 / 84.13] + [(120 - 109.43)^2 / 109.43] + [(85 - 95.57)^2 / 95.57] + [(110 - 107.36)^2 / 107.36] + [(90 - 92.64)^2 / 92.64] + [(90 - 98.89)^2 / 98.89] + [(95 - 86.11)^2 / 86.11] + [(95 - 104.79)^2 / 104.79] + [(100 - 90.21)^2 / 90.21]
#
# Chi-square test statistic ≈ 2.15
#
# Step 5: Determine the degrees of freedom (df) based on the number of rows (r) and number of columns (c):
#
# df = (r - 1) * (c - 1) = (5 - 1) * (2 - 1) = 4
#
# Step 6: Look up the critical chi-square value for the desired significance level and degrees of freedom. Let's assume a significance level of 0.05.
#
# For a chi-square test with df = 4 and a significance level of 0.05, the critical chi-square value is approximately 9.488.
#
# Step 7: Compare the calculated chi-square test statistic with the critical chi-square value:
#
# Since the calculated chi-square test statistic (2.15) is less than the critical chi-square value (9.488), we fail to reject the null hypothesis.
#
# Therefore, based on the chi-square test, there is not enough evidence to conclude that there is a significant difference in the click-through rates between Design A and Design B.

# %%
13. Scenario: A survey is conducted to measure customer satisfaction with a product on a scale of 1 to 10. The data collected is as follows:
    [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
    Calculate the 95% confidence interval for the population mean satisfaction score.

# %% [raw]
# To calculate the 95% confidence interval for the population mean satisfaction score, you can follow these steps:
#
# Step 1: Organize the data:
# Satisfaction scores: [7, 9, 6, 8, 10, 7, 8, 9, 7, 8]
#
# Step 2: Calculate the sample mean and sample standard deviation:
# Sample mean (x̄) = (7 + 9 + 6 + 8 + 10 + 7 + 8 + 9 + 7 + 8) / 10 = 79 / 10 = 7.9
# Sample standard deviation (s) = sqrt([(7 - 7.9)^2 + (9 - 7.9)^2 + (6 - 7.9)^2 + (8 - 7.9)^2 + (10 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2 + (9 - 7.9)^2 + (7 - 7.9)^2 + (8 - 7.9)^2] / 9) ≈ 1.135
#
# Step 3: Calculate the standard error (SE) using the formula:
# SE = s / sqrt(n)
# where:
# s is the sample standard deviation,
# n is the sample size.
#
# SE = 1.135 / sqrt(10) ≈ 0.359
#
# Step 4: Determine the critical value for the desired confidence level. For a 95% confidence level, the critical value corresponds to a z-score of approximately 1.96.
#
# Step 5: Calculate the margin of error (ME) using the formula:
# ME = critical value * SE
#
# ME = 1.96 * 0.359 ≈ 0.704
#
# Step 6: Calculate the lower and upper bounds of the confidence interval:
# Lower bound = x̄ - ME
# Upper bound = x̄ + ME
#
# Lower bound = 7.9 - 0.704 ≈ 7.196
# Upper bound = 7.9 + 0.704 ≈ 8.604
#
# Step 7: Write the confidence interval:
# The 95% confidence interval for the population mean satisfaction score is approximately (7.196, 8.604).
#
# Therefore, we can be 95% confident that the true population mean satisfaction score falls within this interval based on the given sample data.

# %%
14. Scenario: A company wants to analyze the effect of temperature on product performance. The data collected is as follows:
    Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
    Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
    Perform a simple linear regression to predict performance based on temperature.

# %% [raw]
# To perform a simple linear regression to predict performance based on temperature, you can follow these steps:
#
# Step 1: Organize the data:
# Temperature (in degrees Celsius): [20, 22, 23, 19, 21]
# Performance (on a scale of 1 to 10): [8, 7, 9, 6, 8]
#
# Step 2: Calculate the means of the temperature and performance data:
#
# Mean temperature (μx) = (20 + 22 + 23 + 19 + 21) / 5 = 105 / 5 = 21
# Mean performance (μy) = (8 + 7 + 9 + 6 + 8) / 5 = 38 / 5 = 7.6
#
# Step 3: Calculate the deviations from the means for both variables:
#
# Temperature deviations: [(20 - 21), (22 - 21), (23 - 21), (19 - 21), (21 - 21)] = [-1, 1, 2, -2, 0]
# Performance deviations: [(8 - 7.6), (7 - 7.6), (9 - 7.6), (6 - 7.6), (8 - 7.6)] = [0.4, -0.6, 1.4, -1.6, 0.4]
#
# Step 4: Calculate the product of the deviations for each pair of data points:
#
# Deviations product: [-1 * 0.4, 1 * -0.6, 2 * 1.4, -2 * -1.6, 0 * 0.4] = [-0.4, -0.6, 2.8, 3.2, 0]
#
# Step 5: Calculate the sum of the product of the deviations:
#
# Sum of deviations product = -0.4 + -0.6 + 2.8 + 3.2 + 0 = 5
#
# Step 6: Calculate the squared deviations for the temperature variable:
#
# Temperature squared deviations: [(-1)^2, (1)^2, (2)^2, (-2)^2, (0)^2] = [1, 1, 4, 4, 0]
#
# Step 7: Calculate the sum of the squared deviations:
#
# Sum of temperature squared deviations = 1 + 1 + 4 + 4 + 0 = 10
#
# Step 8: Calculate the slope (β1) of the regression line:
#
# β1 = (Sum of deviations product) / (Sum of temperature squared deviations) = 5 / 10 = 0.5
#
# Step 9: Calculate the y-intercept (β0) of the regression line:
#
# β0 = μy - (β1 * μx) = 7.6 - (0.5 * 21) = 7.6 - 10.5 = -2.9
#
# Step 10: Write the equation of the regression line:
#
# Performance = β0 + β1 * Temperature
# Performance = -2.9 + 0.5 * Temperature
#
# Therefore, the equation of the regression line to predict performance based on temperature is Performance = -2.9 + 0.5 * Temperature.

# %%
15. Scenario: A study is conducted to compare the preferences of two groups of participants. The preferences are measured on a Likert scale from 1 to 5. The data collected is as follows:
    Group A: [4, 3, 5, 2, 4]
    Group B: [3, 2, 4, 3, 3]
    Perform a Mann-Whitney U test to determine if there is a significant difference in the median preferences between the two groups.

# %% [raw]
# To perform a Mann-Whitney U test and determine if there is a significant difference in the median preferences between Group A and Group B, you can follow these steps:
#
# Step 1: Organize the data:
# Group A: [4, 3, 5, 2, 4]
# Group B: [3, 2, 4, 3, 3]
#
# Step 2: Rank the combined data in ascending order:
# Combined data: [2, 2, 3, 3, 3, 4, 4, 4, 5]
#
# Step 3: Assign ranks to each observation, considering ties:
# Combined data ranks: [1, 1, 3.5, 3.5, 3.5, 6.5, 6.5, 6.5, 9]
#
# Step 4: Calculate the sum of ranks for each group:
# Sum of ranks for Group A = 1 + 3.5 + 6.5 + 6.5 + 9 = 26
# Sum of ranks for Group B = 2 + 3.5 + 6.5 + 3.5 + 6.5 = 22
#
# Step 5: Calculate the U statistic for each group:
# U statistic for Group A = n1 * n2 + (n1 * (n1 + 1)) / 2 - sum of ranks for Group A
# U statistic for Group A = 5 * 5 + (5 * (5 + 1)) / 2 - 26 = 25
# U statistic for Group B = n1 * n2 + (n1 * (n1 + 1)) / 2 - sum of ranks for Group B
# U statistic for Group B = 5 * 5 + (5 * (5 + 1)) / 2 - 22 = 3
#
# Step 6: Determine the minimum U statistic between the two groups:
# Minimum U statistic = min(U statistic for Group A, U statistic for Group B) = min(25, 3) = 3
#
# Step 7: Calculate the critical U value based on the sample size and desired significance level. Let's assume a significance level of 0.05.
#
# For a two-tailed Mann-Whitney U test with a sample size of 5 in each group and a significance level of 0.05, the critical U value is 3.
#
# Step 8: Compare the minimum U statistic with the critical U value:
#
# Since the minimum U statistic (3) is less than or equal to the critical U value (3), we reject the null hypothesis.
#
# Step 9: Interpretation of the results:
#
# The Mann-Whitney U test indicates that there is a significant difference in the median preferences between Group A and Group B.
#
# Therefore, based on the Mann-Whitney U test, we can conclude that there is a significant difference in the median preferences between the two groups.

# %%
16. Scenario: A company wants to analyze the distribution of customer ages. The data collected is as follows:
    [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
    Calculate the interquartile range (IQR) of the ages.

# %% [raw]
# To calculate the interquartile range (IQR) of the ages, you can follow these steps:
#
# Step 1: Organize the data:
# Ages: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Step 2: Sort the data in ascending order:
# Sorted ages: [25, 30, 35, 40, 45, 50, 55, 60, 65, 70]
#
# Step 3: Calculate the first quartile (Q1):
# Q1 = (n + 1) / 4 = (10 + 1) / 4 = 11 / 4 = 2.75
#
# Since the position of Q1 (2.75) falls between the 2nd and 3rd values in the sorted data, we need to interpolate to find Q1.
#
# Interpolation formula: Value = Value at lower position + (Position - Lower position) * (Value at higher position - Value at lower position)
#
# Value at lower position = 35
# Value at higher position = 40
# Position = 2.75
#
# Q1 = 35 + (2.75 - 2) * (40 - 35) = 35 + 0.75 * 5 = 35 + 3.75 = 38.75
#
# Step 4: Calculate the third quartile (Q3):
# Q3 = 3 * (n + 1) / 4 = 3 * (10 + 1) / 4 = 33 / 4 = 8.25
#
# Since the position of Q3 (8.25) falls between the 8th and 9th values in the sorted data, we need to interpolate to find Q3.
#
# Value at lower position = 55
# Value at higher position = 60
# Position = 8.25
#
# Q3 = 55 + (8.25 - 8) * (60 - 55) = 55 + 0.25 * 5 = 55 + 1.25 = 56.25
#
# Step 5: Calculate the interquartile range (IQR):
# IQR = Q3 - Q1 = 56.25 - 38.75 = 17.5
#
# Therefore, the interquartile range (IQR) of the ages is 17.5. This means that the middle 50% of the ages fall within a range of 17.5 years.

# %%
17. Scenario: A study is conducted to compare the performance of three different machine learning algorithms. The accuracy scores for each algorithm are as follows:
    Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
    Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
    Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
    Perform a Kruskal-Wallis test to determine if there is a significant difference in the median accuracy scores between the algorithms.

# %% [raw]
# To perform a Kruskal-Wallis test and determine if there is a significant difference in the median accuracy scores between Algorithm A, Algorithm B, and Algorithm C, you can follow these steps:
#
# Step 1: Organize the data:
# Algorithm A: [0.85, 0.80, 0.82, 0.87, 0.83]
# Algorithm B: [0.78, 0.82, 0.84, 0.80, 0.79]
# Algorithm C: [0.90, 0.88, 0.89, 0.86, 0.87]
#
# Step 2: Combine the data into a single ranked dataset, including ties:
# Ranked data: [0.78, 0.79, 0.80, 0.80, 0.82, 0.83, 0.84, 0.85, 0.86, 0.87, 0.87, 0.88, 0.89, 0.90]
#
# Step 3: Assign ranks to each observation:
# Ranked data ranks: [1, 2, 3.5, 3.5, 5, 6, 7, 8, 9, 10.5, 10.5, 12, 13, 14]
#
# Step 4: Calculate the sum of ranks for each group:
# Sum of ranks for Algorithm A = 1 + 2 + 3.5 + 5 + 6 = 17.5
# Sum of ranks for Algorithm B = 3.5 + 7 + 8 + 10.5 + 13 = 42
# Sum of ranks for Algorithm C = 9 + 10.5 + 12 + 14 = 45.5
#
# Step 5: Calculate the Kruskal-Wallis test statistic (H):
# H = (12 * (Sum of ranks squared) / (Sum of ranks) - (3 * (Number of groups + 1))) / (3 * (Number of groups - 1))
#
# H = (12 * ((17.5)^2 + 42^2 + 45.5^2) / (17.5 + 42 + 45.5) - (3 * (3 + 1))) / (3 * (3 - 1))
# H = (12 * (306.25 + 1764 + 2070.25) / (105.5) - (3 * 4)) / (6)
# H = (12 * (4140.5) / (105.5) - 12) / 6
# H = (49686 / 105.5 - 12) / 6
# H = (470.86 - 12) / 6
# H = 458.86 / 6
# H ≈ 76.48
#
# Step 6: Determine the critical value for the desired significance level and degrees of freedom. Let's assume a significance level of 0.05.
#
# For a Kruskal-Wallis test with 3 groups and a significance level of 0.05, the critical value is approximately 5.991.
#
# Step 7: Compare the calculated test statistic with the critical value:
#
# Since the calculated test statistic (76.48) is greater than the critical value (5.991), we reject the null hypothesis.
#
# Step 8: Interpretation of the results:
#
# The Kruskal-Wallis test indicates that there is a significant difference in the median accuracy scores between the algorithms.
#
# Therefore, based on the Kruskal-Wallis test, we can conclude that there is a significant difference in the median accuracy scores between Algorithm A, Algorithm B, and Algorithm C.

# %%
18. Scenario: A company wants to analyze the effect of price on sales. The data collected is as follows:
    Price (in dollars): [10, 15, 12, 8, 14]
    Sales: [100, 80, 90, 110, 95]
    Perform a simple linear regression to predict

 sales based on price.

# %% [raw]
# To perform a simple linear regression to predict sales based on price, you can follow these steps:
#
# Step 1: Organize the data:
# Price (in dollars): [10, 15, 12, 8, 14]
# Sales: [100, 80, 90, 110, 95]
#
# Step 2: Calculate the means of the price and sales data:
#
# Mean price (μx) = (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
# Mean sales (μy) = (100 + 80 + 90 + 110 + 95) / 5 = 475 / 5 = 95
#
# Step 3: Calculate the deviations from the means for both variables:
#
# Price deviations: [(10 - 11.8), (15 - 11.8), (12 - 11.8), (8 - 11.8), (14 - 11.8)] = [-1.8, 3.2, 0.2, -3.8, 2.2]
# Sales deviations: [(100 - 95), (80 - 95), (90 - 95), (110 - 95), (95 - 95)] = [5, -15, -5, 15, 0]
#
# Step 4: Calculate the product of the deviations for each pair of data points:
#
# Deviations product: [-1.8 * 5, 3.2 * -15, 0.2 * -5, -3.8 * 15, 2.2 * 0] = [-9, -48, -1, -57, 0]
#
# Step 5: Calculate the sum of the product of the deviations:
#
# Sum of deviations product = -9 + -48 + -1 + -57 + 0 = -115
#
# Step 6: Calculate the squared deviations for the price variable:
#
# Price squared deviations: [(-1.8)^2, (3.2)^2, (0.2)^2, (-3.8)^2, (2.2)^2] = [3.24, 10.24, 0.04, 14.44, 4.84]
#
# Step 7: Calculate the sum of the squared deviations:
#
# Sum of price squared deviations = 3.24 + 10.24 + 0.04 + 14.44 + 4.84 = 33.8
#
# Step 8: Calculate the slope (β1) of the regression line:
#
# β1 = (Sum of deviations product) / (Sum of squared deviations) = -115 / 33.8 ≈ -3.40
#
# Step 9: Calculate the y-intercept (β0) of the regression line:
#
# β0 = μy - (β1 * μx) = 95 - (-3.40 * 11.8) = 95 + 40.12 = 135.12
#
# Step 10: Write the equation of the regression line:
#
# Sales = β0 + β1 * Price
# Sales = 135.12 - 3.40 * Price
#
# Therefore, the equation of the regression line to predict sales based on price is Sales = 135.12 - 3.40 * Price.

# %%
19. Scenario: A survey is conducted to measure the satisfaction levels of customers with a new product. The data collected is as follows:
    [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
    Calculate the standard error of the mean satisfaction score.

# %% [raw]
# To calculate the standard error of the mean satisfaction score, you can follow these steps:
#
# Step 1: Organize the data:
# Satisfaction scores: [7, 8, 9, 6, 8, 7, 9, 7, 8, 7]
#
# Step 2: Calculate the sample mean and sample standard deviation:
# Sample mean (x̄) = (7 + 8 + 9 + 6 + 8 + 7 + 9 + 7 + 8 + 7) / 10 = 76 / 10 = 7.6
# Sample standard deviation (s) = sqrt([(7 - 7.6)^2 + (8 - 7.6)^2 + (9 - 7.6)^2 + (6 - 7.6)^2 + (8 - 7.6)^2 + (7 - 7.6)^2 + (9 - 7.6)^2 + (7 - 7.6)^2 + (8 - 7.6)^2 + (7 - 7.6)^2] / 9) ≈ 0.894
#
# Step 3: Calculate the standard error (SE) using the formula:
# SE = s / sqrt(n)
# where:
# s is the sample standard deviation,
# n is the sample size.
#
# SE = 0.894 / sqrt(10) ≈ 0.283
#
# Therefore, the standard error of the mean satisfaction score is approximately 0.283.

# %%
20. Scenario: A company wants to analyze the relationship between advertising expenditure and sales. The data collected is as follows:
    Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
    Sales (in thousands): [25, 30, 28, 20, 26]
    Perform a multiple regression analysis to predict sales based on advertising expenditure.

# %% [raw]
# To perform a multiple regression analysis to predict sales based on advertising expenditure, you can follow these steps:
#
# Step 1: Organize the data:
# Advertising Expenditure (in thousands): [10, 15, 12, 8, 14]
# Sales (in thousands): [25, 30, 28, 20, 26]
#
# Step 2: Calculate the means of the advertising expenditure and sales data:
#
# Mean advertising expenditure (μx) = (10 + 15 + 12 + 8 + 14) / 5 = 59 / 5 = 11.8
# Mean sales (μy) = (25 + 30 + 28 + 20 + 26) / 5 = 129 / 5 = 25.8
#
# Step 3: Calculate the deviations from the means for both variables:
#
# Advertising expenditure deviations: [(10 - 11.8), (15 - 11.8), (12 - 11.8), (8 - 11.8), (14 - 11.8)] = [-1.8, 3.2, 0.2, -3.8, 2.2]
# Sales deviations: [(25 - 25.8), (30 - 25.8), (28 - 25.8), (20 - 25.8), (26 - 25.8)] = [-0.8, 4.2, 2.2, -5.8, 0.2]
#
# Step 4: Calculate the product of the deviations for each pair of data points:
#
# Deviations product: [-1.8 * -0.8, 3.2 * 4.2, 0.2 * 2.2, -3.8 * -5.8, 2.2 * 0.2] = [1.44, 13.44, 0.44, 22.04, 0.44]
#
# Step 5: Calculate the sum of the product of the deviations:
#
# Sum of deviations product = 1.44 + 13.44 + 0.44 + 22.04 + 0.44 = 37.8
#
# Step 6: Calculate the squared deviations for the advertising expenditure variable:
#
# Advertising expenditure squared deviations: [(-1.8)^2, (3.2)^2, (0.2)^2, (-3.8)^2, (2.2)^2] = [3.24, 10.24, 0.04, 14.44, 4.84]
#
# Step 7: Calculate the sum of the squared deviations:
#
# Sum of advertising expenditure squared deviations = 3.24 + 10.24 + 0.04 + 14.44 + 4.84 = 32.8
#
# Step 8: Calculate the regression coefficients (β1 and β0) using the formulas:
#
# β1 = (Sum of deviations product) / (Sum of squared deviations) = 37.8 / 32.8 ≈ 1.15
# β0 = μy - (β1 * μx) = 25.8 - (1.15 * 11.8) = 25.8 - 13.57 ≈ 12.23
#
# Step 9: Write the equation of the multiple regression line:
#
# Sales = β0 + β1 * Advertising Expenditure
# Sales = 12.23 + 1.15 * Advertising Expenditure
#
# Therefore, the equation of the multiple regression line to predict sales based on advertising expenditure is Sales = 12.23 + 1.15 * Advertising Expenditure.
