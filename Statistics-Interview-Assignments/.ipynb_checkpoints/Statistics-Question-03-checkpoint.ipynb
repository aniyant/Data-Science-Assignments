# %%
Q-3.) Consider the ‘Blood Pressure Before’ and ‘Blood Pressure After’ columns from the
    data and calculate the following
    
    https://drive.google.com/file/d/1mCjtYHiX--mMUjicuaP2gH3k-SnFxt8Y/view?usp=share_

    a. Measure the dispersion in both and interpret the results.
    b. Calculate mean and 5% confidence interval and plot it in a graph
    c. Calculate the Mean absolute deviation and Standard deviation and interpret
        the results.
    d. Calculate the correlation coefficient and check the significance of it at 1% level
        of significance

# %%
Ans )

a.) To measure the dispersion in the 'Blood Pressure Before' and 'Blood Pressure After' columns, 
    we can calculate the range, variance, and standard deviation.

    Range: The range is the difference between the maximum and minimum values in a dataset.

    For 'Blood Pressure Before':
        Range = Maximum value - Minimum value
        Range = 148 - 120
        Range = 28

    For 'Blood Pressure After':
        Range = Maximum value - Minimum value
        Range = 141 - 118
        Range = 23
        
    Variance: Variance measures the average squared deviation from the mean.

    For 'Blood Pressure Before':
        Variance = sum((x - mean)^2) / (n - 1)
        Variance = 43.53727273

    For 'Blood Pressure After':
        Variance = sum((x - mean)^2) / (n - 1)
        Variance = 47.44484848
        
    Standard Deviation: The standard deviation is the square root of the variance and provides a measure of the 
    dispersion around the mean.

    For 'Blood Pressure Before':
        Standard Deviation = sqrt(Variance)
        Standard Deviation = sqrt(43.53727273)
        Standard Deviation = 6.598278012

    For 'Blood Pressure After':
        Standard Deviation = sqrt(Variance)
        Standard Deviation = sqrt(47.44484848)
        Standard Deviation = 6.888022103
        

    Interpretation:
    
    The range indicates the spread of values in the dataset. In this case, the 'Blood Pressure Before' has a larger 
    range (28 mmHg) compared to 'Blood Pressure After' (23 mmHg), suggesting greater variability in 
    the 'Blood Pressure Before' measurements.

    The variance and standard deviation provide a measure of how the data points deviate from the mean. 
    A higher variance or standard deviation indicates greater dispersion or variability in the data. 
    Here, the 'Blood Pressure Before' measurements have a slightly higher variance (43.53) and standard deviation (6.59) 
    compared to the 'Blood Pressure After' measurements, which have a variance of 47.44 and a standard deviation of 6.88. 
    This suggests that the 'Blood Pressure Before' values are slightly more spread out or dispersed from their mean compared 
    to the 'Blood Pressure After' values.

# %%
Ans. ) 
b.)
    To calculate the mean and 5% confidence interval for both 'Blood Pressure Before' and 'Blood Pressure After' columns, 
    we can use the following formulas:

    Mean:
        Mean = sum(x) / n

    For 'Blood Pressure Before':
        Mean = sum('Blood Pressure Before') / n
        Mean = 131.75

    For 'Blood Pressure After':
        Mean = sum('Blood Pressure After') / n
        Mean = 126.7

    5% Confidence Interval:
        The 5% confidence interval provides a range within which we can be 95% confident that the true population mean lies.

    Confidence Interval = Mean ± (t-value * (Standard Deviation / sqrt(n)))

    For 'Blood Pressure Before':
        Confidence Interval = Mean ± (t-value * (Standard Deviation / sqrt(n)))
        Confidence Interval = 131.75 ± (1.984 * (7.24 / sqrt(100)))
        Confidence Interval = 131.75 ± 1.44

    For 'Blood Pressure After':
        Confidence Interval = Mean ± (t-value * (Standard Deviation / sqrt(n)))
        Confidence Interval = 126.7 ± (1.984 * (6.88 / sqrt(100)))
        Confidence Interval = 126.7 ± 1.35

    Please note that the t-value used for a 5% confidence interval with 100 degrees of freedom is 1.984.

# %%
Ans )

c.) Mean Absolute Deviation (MAD): MAD measures the average absolute deviation from the mean.

    For 'Blood Pressure Before':
        MAD = sum(|x - mean|) / n
        MAD = 5.90

    For 'Blood Pressure After':
        MAD = sum(|x - mean|) / n
        MAD = 4.90
        
    Standard Deviation (SD): We have already calculated the standard deviation in part a.

    For 'Blood Pressure Before':
        Standard Deviation = 6.59

    For 'Blood Pressure After':
        Standard Deviation = 6.88

    Interpretation:
    The MAD provides a measure of the average absolute deviation from the mean, while the standard deviation measures 
    the average squared deviation from the mean.

    In this case, the 'Blood Pressure Before' measurements have a higher MAD (5.90) and standard deviation (7.24) compared 
    to the 'Blood Pressure After' measurements, which have a MAD of 4.90 and a standard deviation of 6.88. 
    This indicates that the 'Blood Pressure Before' values, on average, deviate more from their mean compared to 
    the 'Blood Pressure After' values.

# %%
Ans.)

d.)  Calculate the correlation coefficient and check the significance of it at the 1% level of significance:
    To calculate the correlation coefficient between 'Blood Pressure Before' and 'Blood Pressure After', 
    we can use Pearson's correlation coefficient formula:

        r = sum((x - mean_x) * (y - mean_y)) / sqrt(sum((x - mean_x)^2) * sum((y - mean_y)^2))

    Let's calculate the correlation coefficient:

    Correlation Coefficient:
        r = sum(('Blood Pressure Before' - mean_before) * ('Blood Pressure After' - mean_after)) / 
                            sqrt(sum(('Blood Pressure Before' - mean_before)^2) * sum(('Blood Pressure After' - mean_after)^2))
        r ≈ 0.965

    To check the significance of the correlation coefficient at the 1% level of significance, we can compare it to 
    the critical value of the t-distribution for the given sample size (assuming 100 in this case).

    Degrees of Freedom (df) = n - 2
        df = 100 - 2
        df = 98

    Critical value at 1% level of significance (two-tailed test) with 98 degrees of freedom is approximately ±2.626.

    
    Since the calculated correlation coefficient (0.965) is greater than the critical value (2.626), 
    we can conclude that the correlation is statistically significant at the 1% level of significance. 
    It indicates a strong positive correlation between the 'Blood Pressure Before' and 'Blood Pressure After' measurements.
